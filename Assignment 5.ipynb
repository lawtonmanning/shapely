# %%
import shap_utils
# Out:
# /mnt/d/Documents/Jupyter/Data Mining/Assignments/5/DataShapley/shap_utils.py:180: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if problem is 'classification':
# /mnt/d/Documents/Jupyter/Data Mining/Assignments/5/DataShapley/shap_utils.py:183: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif problem is 'regression':
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-dcc0c68eb6f6> in <module>
# ----> 1 import shap_utils
#
# /mnt/d/Documents/Jupyter/Data Mining/Assignments/5/DataShapley/shap_utils.py in <module>
#      18 from sklearn.base import clone
#      19 import inspect
# ---> 20 from Shapley import ShapNN, CShapNN
#      21 from multiprocessing import dummy as multiprocessing
#      22 from sklearn.metrics import roc_auc_score, f1_score
#
# /mnt/d/Documents/Jupyter/Data Mining/Assignments/5/DataShapley/Shapley.py in <module>
# ...
